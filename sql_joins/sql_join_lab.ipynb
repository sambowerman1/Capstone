# %%
#joins for wikipedia_api_scraper/output_v2.csv and ai_summarizer/output.csv

wikipedia_api_scraper_path = "../wikipedia_api_scraper/output_v2.csv"
ai_summarizer_path = "../ai_summarizer/wikipedia_extraction/human_evaluated_output.csv"

import pandas as pd

wikipedia_api_scraper = pd.read_csv(wikipedia_api_scraper_path)
ai_summarizer = pd.read_csv(ai_summarizer_path)
ai_summarizer.rename(columns={"name": "Name"}, inplace=True)

left_join = wikipedia_api_scraper.merge(ai_summarizer, on='Name', how='left')
right_join = wikipedia_api_scraper.merge(ai_summarizer, on='Name', how='right')
left_join_nulls = left_join[left_join['wikipedia_url'].isna()].copy()
right_join_nulls = right_join[right_join['Wikipedia Link'].isna()].copy()
inner_join = wikipedia_api_scraper.merge(ai_summarizer, on='Name', how='inner')

# %%
# Build DataFrames where Wikipedia links match vs don't match (based on inner_join)

# Normalize link strings for robust equality (trim, lowercase, https, no trailing slash)
def _normalize_links(series):
    return (
        series.fillna("")
              .str.strip()
              .str.lower()
              .str.replace("http://", "https://", regex=False)
              .str.rstrip("/")
    )

left_link_norm = _normalize_links(inner_join["Wikipedia Link"]) if "Wikipedia Link" in inner_join.columns else None
right_link_norm = _normalize_links(inner_join["wikipedia_url"]) if "wikipedia_url" in inner_join.columns else None

# Match only when both present and normalized values are identical
both_present = inner_join["Wikipedia Link"].notna() & inner_join["wikipedia_url"].notna()
link_match_mask = both_present & (left_link_norm == right_link_norm)

links_match_df = inner_join[link_match_mask].copy()
links_non_match_df = inner_join[~link_match_mask].copy()

print(f"Exact link matches: {len(links_match_df)}")
print(f"Non-matches (including missing): {len(links_non_match_df)}")
# Out:
# Exact link matches: 35
# Non-matches (including missing): 253

# %%
links_match_df
# Out:
#                            Name        Primary Occupation               Race  \
# 1                   Allan Bense                politician                NaN
# 8                Harriet Tubman                    writer  African Americans
# 9                Harriet Tubman                    writer  African Americans
# 32           Carmelau Monestime         radio personality                NaN
# 40             Larcenia Bullard                politician                NaN
# 41                   Betty Pino                 announcer                NaN
# 45             C. Bette Wimbish                    lawyer                NaN
# 55          Albert W. Gilchrist                politician                NaN
# 74                Claude Pepper                politician                NaN
# 85            Billy Bowlegs III                       NaN                NaN
# 103          St. Elmo W. Acosta                       NaN                NaN
# 106            Raeburn C. Horne                politician                NaN
# 124            Verle Allyn Pope                politician                NaN
# 129          Robert L. F. Sikes                politician                NaN
# 134            George G. Tapper                politician                NaN
# 140              Danny Wuerffel  American football player                NaN
# 152          Robert L. F. Sikes                politician                NaN
# 166           Merrill P. Barber                politician                NaN
# 168                 Dan McCarty                politician                NaN
# 203            Hamilton Disston            businessperson                NaN
# 205           Douglas Stenstrom                    lawyer                NaN
# 209               Anne Ackerman                  activist                NaN
# 214             Carlos Arboleya        rugby union player                NaN
# 215              Carrie P. Meek                politician  African Americans
# 218               Elaine Gordon                politician                NaN
# 224                 Gwen Cherry                   teacher                NaN
# 229                 Jim Mandich  American football player                NaN
# 230            John F. Cosgrove                politician                NaN
# 233                Julia Tuttle            businessperson                NaN
# 234                Julia Tuttle            businessperson                NaN
# 237                Manolo Reyes                journalist                NaN
# 250  Saint Marcellin Champagnat           Catholic priest                NaN
# 257         W. Howard Frankland            businessperson                NaN
# 283                George Crady                politician                NaN
# 284           Christa McAuliffe                 astronaut                NaN
#
#         Sex  Birth Date  Death Date  \
# 1      male  1951-10-06         NaN
# 8    female  1821-00-00  1913-03-10
# 9    female  1821-00-00  1913-03-10
# 32     male  1931-04-06  2016-01-16
# 40   female  1947-07-21  2013-03-16
# 41   female  1948-04-21  2013-08-07
# 45   female  1924-03-24  2009-11-30
# 55     male  1858-01-15  1926-05-15
# 74     male  1900-09-08  1989-05-30
# 85     male  1862-01-01  1965-01-01
# 103    male  1875-01-01  1947-01-01
# 106    male  1896-10-07  1962-11-06
# 124    male  1903-12-12  1973-07-18
# 129    male  1906-06-03  1994-09-28
# 134    male  1916-01-01  1986-01-01
# 140    male  1974-05-27         NaN
# 152    male  1906-06-03  1994-09-28
# 166    male  1910-12-18  1985-12-21
# 168    male  1912-01-18  1953-09-28
# 203    male  1844-08-23  1896-04-30
# 205    male  1921-09-05  2010-06-23
# 209  female  1914-00-00  1989-03-01
# 214    male  1985-07-23         NaN
# 215  female  1926-04-29  2021-11-28
# 218  female  1931-00-00  2000-02-25
# 224  female  1923-08-27  1979-02-07
# 229    male  1948-07-30  2011-04-26
# 230    male  1949-07-01  2006-04-19
# 233  female  1849-01-22  1898-09-14
# 234  female  1849-01-22  1898-09-14
# 237    male  1924-07-29  2008-01-03
# 250    male  1789-05-20  1840-06-06
# 257    male  1901-11-26  1980-12-17
# 283    male  1931-06-14         NaN
# 284  female  1948-09-02  1986-01-28
#
#                                         Wikipedia Link  \
# 1            https://en.wikipedia.org/wiki/Allan_Bense
# 8         https://en.wikipedia.org/wiki/Harriet_Tubman
# 9         https://en.wikipedia.org/wiki/Harriet_Tubman
# 32    https://en.wikipedia.org/wiki/Carmelau_Monestime
# 40      https://en.wikipedia.org/wiki/Larcenia_Bullard
# 41            https://en.wikipedia.org/wiki/Betty_Pino
# 45      https://en.wikipedia.org/wiki/C._Bette_Wimbish
# 55   https://en.wikipedia.org/wiki/Albert_W._Gilchrist
# 74         https://en.wikipedia.org/wiki/Claude_Pepper
# 85     https://en.wikipedia.org/wiki/Billy_Bowlegs_III
# 103   https://en.wikipedia.org/wiki/St._Elmo_W._Acosta
# 106     https://en.wikipedia.org/wiki/Raeburn_C._Horne
# 124        https://en.wikipedia.org/wiki/Verle_A._Pope
# 129            https://en.wikipedia.org/wiki/Bob_Sikes
# 134     https://en.wikipedia.org/wiki/George_G._Tapper
# 140       https://en.wikipedia.org/wiki/Danny_Wuerffel
# 152            https://en.wikipedia.org/wiki/Bob_Sikes
# 166    https://en.wikipedia.org/wiki/Merrill_P._Barber
# 168    https://en.wikipedia.org/wiki/Daniel_T._McCarty
# 203     https://en.wikipedia.org/wiki/Hamilton_Disston
# 205    https://en.wikipedia.org/wiki/Douglas_Stenstrom
# 209       https://en.wikipedia.org/wiki/Annie_Ackerman
# 214      https://en.wikipedia.org/wiki/Carlos_Arboleya
# 215          https://en.wikipedia.org/wiki/Carrie_Meek
# 218        https://en.wikipedia.org/wiki/Elaine_Gordon
# 224          https://en.wikipedia.org/wiki/Gwen_Cherry
# 229          https://en.wikipedia.org/wiki/Jim_Mandich
# 230     https://en.wikipedia.org/wiki/John_F._Cosgrove
# 233         https://en.wikipedia.org/wiki/Julia_Tuttle
# 234         https://en.wikipedia.org/wiki/Julia_Tuttle
# 237         https://en.wikipedia.org/wiki/Manolo_Reyes
# 250  https://en.wikipedia.org/wiki/Marcellin_Champa...
# 257  https://en.wikipedia.org/wiki/William_Howard_F...
# 283         https://en.wikipedia.org/wiki/George_Crady
# 284    https://en.wikipedia.org/wiki/Christa_McAuliffe
#
#                       original_designation             county  \
# 1                      Allan Bense Highway                Bay
# 8     Harriet Tubman Highway/U.S. 1/S.R. 5         Miami-Dade
# 9    Harriet Tubman Highway/State Road 909         Miami-Dade
# 32               Carmelau Monestime Street         Miami‐Dade
# 40                    Larcenia Bullard Way         Miami‐Dade
# 41                          Betty Pino Way         Miami‐Dade
# 45                C. Bette Wimbish Highway           Pinellas
# 55              Albert W. Gilchrist Bridge          Charlotte
# 74          Claude Pepper Memorial Highway  Multiple Counties
# 85                Billy Bowlegs III Bridge         Okeechobee
# 103              St. Elmo W. Acosta Bridge              Duval
# 106      Raeburn C. Horne Memorial Highway            Madison
# 124                Verle Allyn Pope Bridge          St. Johns
# 129              Robert L. F. Sikes Bridge           Escambia
# 134                George G. Tapper Bridge               Gulf
# 140                     Danny Wuerffel Way           Okaloosa
# 152              Robert L. F. Sikes Bridge           Escambia
# 166               Merrill P. Barber Bridge       Indian River
# 168           Dan McCarty Memorial Highway  Multiple Counties
# 203                Hamilton Disston Bridge               Polk
# 205               Douglas Stenstrom Bridge            Volusia
# 209                Anne Ackerman Boulevard         Miami‐Dade
# 214              Carlos Arboleya Boulevard         Miami‐Dade
# 215               Carrie P. Meek Boulevard         Miami‐Dade
# 218                  Elaine Gordon Highway         Miami‐Dade
# 224                    Gwen Cherry Highway         Miami‐Dade
# 229           Jim Mandich Memorial Highway         Miami‐Dade
# 230               John F. Cosgrove Highway         Miami‐Dade
# 233                       Julia Tuttle Way         Miami‐Dade
# 234                       Julia Tuttle Way         Miami‐Dade
# 237                       Manolo Reyes Way         Miami‐Dade
# 250         Saint Marcellin Champagnat Way         Miami‐Dade
# 257             W. Howard Frankland Bridge       Hillsborough
# 283                    George Crady Bridge  Multiple Counties
# 284               Christa McAuliffe Bridge            Brevard
#
#                                          wikipedia_url  ...  \
# 1            https://en.wikipedia.org/wiki/Allan_Bense  ...
# 8         https://en.wikipedia.org/wiki/Harriet_Tubman  ...
# 9         https://en.wikipedia.org/wiki/Harriet_Tubman  ...
# 32    https://en.wikipedia.org/wiki/Carmelau_Monestime  ...
# 40      https://en.wikipedia.org/wiki/Larcenia_Bullard  ...
# 41            https://en.wikipedia.org/wiki/Betty_Pino  ...
# 45      https://en.wikipedia.org/wiki/C._Bette_Wimbish  ...
# 55   https://en.wikipedia.org/wiki/Albert_W._Gilchrist  ...
# 74         https://en.wikipedia.org/wiki/Claude_Pepper  ...
# 85     https://en.wikipedia.org/wiki/Billy_Bowlegs_III  ...
# 103   https://en.wikipedia.org/wiki/St._Elmo_W._Acosta  ...
# 106     https://en.wikipedia.org/wiki/Raeburn_C._Horne  ...
# 124        https://en.wikipedia.org/wiki/Verle_A._Pope  ...
# 129            https://en.wikipedia.org/wiki/Bob_Sikes  ...
# 134     https://en.wikipedia.org/wiki/George_G._Tapper  ...
# 140       https://en.wikipedia.org/wiki/Danny_Wuerffel  ...
# 152            https://en.wikipedia.org/wiki/Bob_Sikes  ...
# 166    https://en.wikipedia.org/wiki/Merrill_P._Barber  ...
# 168    https://en.wikipedia.org/wiki/Daniel_T._McCarty  ...
# 203     https://en.wikipedia.org/wiki/Hamilton_Disston  ...
# 205    https://en.wikipedia.org/wiki/Douglas_Stenstrom  ...
# 209       https://en.wikipedia.org/wiki/Annie_Ackerman  ...
# 214      https://en.wikipedia.org/wiki/Carlos_Arboleya  ...
# 215          https://en.wikipedia.org/wiki/Carrie_Meek  ...
# 218        https://en.wikipedia.org/wiki/Elaine_Gordon  ...
# 224          https://en.wikipedia.org/wiki/Gwen_Cherry  ...
# 229          https://en.wikipedia.org/wiki/Jim_Mandich  ...
# 230     https://en.wikipedia.org/wiki/John_F._Cosgrove  ...
# 233         https://en.wikipedia.org/wiki/Julia_Tuttle  ...
# 234         https://en.wikipedia.org/wiki/Julia_Tuttle  ...
# 237         https://en.wikipedia.org/wiki/Manolo_Reyes  ...
# 250  https://en.wikipedia.org/wiki/Marcellin_Champa...  ...
# 257  https://en.wikipedia.org/wiki/William_Howard_F...  ...
# 283         https://en.wikipedia.org/wiki/George_Crady  ...
# 284    https://en.wikipedia.org/wiki/Christa_McAuliffe  ...
#
#                                              education         dob  \
# 1    ['University of West Florida, Bachelor of Arts...  1947-10-25
# 8                                                  NaN  1822-01-01
# 9                                                  NaN  1822-01-01
# 32                                                 NaN         NaN
# 40                                                 NaN  1947-01-01
# 41                                                 NaN         NaN
# 45   ["Virginia State University, Bachelor's degree...  1924-01-01
# 55   ['East Florida Seminary (now part of the Unive...  1858-01-15
# 74   ['University of Alabama, Bachelor of Arts', 'H...  1900-09-08
# 85                                                 NaN  1910-01-01
# 103                                                NaN         NaN
# 106                                                NaN         NaN
# 124                                                NaN  1930-03-12
# 129                                                NaN  1906-08-14
# 134                                                NaN  1864-01-01
# 140  ['Fort Walton Beach High School, Florida', "Un...  1974-05-27
# 152                                                NaN  1906-08-14
# 166                                                NaN         NaN
# 168  ['University of Florida, Bachelor of Science i...  1912-12-24
# 203                                                NaN  1844-08-23
# 205                                                NaN         NaN
# 209                                                NaN         NaN
# 214                                                NaN         NaN
# 215  ['Florida A&M University, Bachelor of Science'...  1926-04-29
# 218                                                NaN  1943-01-01
# 224  ['Florida Agricultural and Mechanical Universi...  1923-01-23
# 229  ['University of Michigan', "Bachelor's degree ...  1948-07-30
# 230                                                NaN         NaN
# 233                                                NaN  1849-01-01
# 234                                                NaN  1849-01-01
# 237                                                NaN         NaN
# 250  ['Seminary of Saint-Irénée, Lyon', 'Theologica...  1789-05-20
# 257                                                NaN         NaN
# 283                                                NaN         NaN
# 284  ['Framingham State College, Bachelor of Arts i...  1948-09-02
#
#             dod                              place_of_birth  \
# 1    2014-07-10           Pensacola, Florida, United States
# 8    1913-03-10  Dorchester County, Maryland, United States
# 9    1913-03-10  Dorchester County, Maryland, United States
# 32          NaN                                   not found
# 40   2023-01-01                                   not found
# 41   1979-11-18                                   not found
# 45   2016-01-01         Petersburg, Virginia, United States
# 55   1926-05-15       Nassau County, Florida, United States
# 74   1989-05-30         Dudleyville, Alabama, United States
# 85   1965-01-01                      Florida, United States
# 103         NaN                                   not found
# 106         NaN                                   not found
# 124  2020-12-17                  Provo, Utah, United States
# 129  1994-09-29           Isola, Mississippi, United States
# 134         NaN                                   not found
# 140         NaN           Pensacola, Florida, United States
# 152  1994-09-29           Isola, Mississippi, United States
# 166         NaN                                   not found
# 168  1953-09-28         Fort Pierce, Florida, United States
# 203  1896-04-30   Philadelphia, Pennsylvania, United States
# 205         NaN                                   not found
# 209         NaN                                   not found
# 214         NaN                                   not found
# 215  2021-11-28         Tallahassee, Florida, United States
# 218  2022-01-01                                   not found
# 224  1979-02-16               Miami, Florida, United States
# 229  2011-04-26              Cleveland, Ohio, United States
# 230         NaN                                   not found
# 233  1898-09-14              Cleveland, Ohio, United States
# 234  1898-09-14              Cleveland, Ohio, United States
# 237  2019-01-01                                   not found
# 250  1840-06-06                     Le Rosey, Loire, France
# 257         NaN                                   not found
# 283         NaN                                   not found
# 284  1986-01-28        Boston, Massachusetts, United States
#
#                                         place_of_death     gender  \
# 1                    Pensacola, Florida, United States       male
# 8                      Auburn, New York, United States     female
# 9                      Auburn, New York, United States     female
# 32                                           not found  not found
# 40                                           not found     female
# 41                                   Jonestown, Guyana     female
# 45                                           not found     female
# 55                 Gainesville, Florida, United States       male
# 74                     Washington, D.C., United States       male
# 85                              Florida, United States       male
# 103                                          not found       male
# 106                                          not found       male
# 124                                          not found       male
# 129                  Crestview, Florida, United States       male
# 134                                          not found       male
# 140                                          not found       male
# 152                  Crestview, Florida, United States       male
# 166                                          not found       male
# 168                Tallahassee, Florida, United States       male
# 203          Philadelphia, Pennsylvania, United States       male
# 205                                          not found       male
# 209                                          not found     female
# 214                                          not found       male
# 215                      Miami, Florida, United States     female
# 218                                          not found     female
# 224                      Miami, Florida, United States     female
# 229                      Miami, Florida, United States       male
# 230                                          not found       male
# 233                      Miami, Florida, United States     female
# 234                      Miami, Florida, United States     female
# 237                                          not found       male
# 250                       Saint-Chamond, Loire, France       male
# 257                                          not found  not found
# 283                                          not found       male
# 284  Over the Atlantic Ocean, off the coast of Cape...     female
#
#     involved_in_sports involved_in_politics involved_in_military  \
# 1                   no                  yes                   no
# 8                   no                  yes                  yes
# 9                   no                  yes                  yes
# 32                  no                   no                   no
# 40                  no                  yes                   no
# 41                  no                   no                   no
# 45                  no                  yes                   no
# 55                  no                  yes                  yes
# 74                  no                  yes                  yes
# 85                  no                  yes                   no
# 103                 no                   no                   no
# 106                 no                   no                   no
# 124                 no                  yes                   no
# 129                 no                  yes                  yes
# 134                 no                   no                   no
# 140                yes                   no                   no
# 152                 no                  yes                  yes
# 166                 no                  yes                  yes
# 168                 no                  yes                  yes
# 203                 no                  yes                   no
# 205                 no                   no                   no
# 209                 no                  yes                   no
# 214                yes                   no                   no
# 215                 no                  yes                   no
# 218                 no                  yes                   no
# 224                 no                  yes                   no
# 229                yes                   no                   no
# 230                 no                  yes                   no
# 233                 no                   no                   no
# 234                 no                   no                   no
# 237                 no                   no                   no
# 250                 no                   no                   no
# 257                 no                   no                   no
# 283                 no                  yes                   no
# 284                 no                   no                   no
#
#     involved_in_music
# 1                  no
# 8                  no
# 9                  no
# 32                 no
# 40                 no
# 41                 no
# 45                 no
# 55                 no
# 74                 no
# 85                 no
# 103                no
# 106                no
# 124                no
# 129                no
# 134                no
# 140                no
# 152                no
# 166                no
# 168                no
# 203                no
# 205                no
# 209                no
# 214                no
# 215                no
# 218                no
# 224                no
# 229                no
# 230                no
# 233                no
# 234                no
# 237                no
# 250                no
# 257                no
# 283                no
# 284                no
#
# [35 rows x 25 columns]

# %%
links_non_match_df
# Out:
#                                           Name Primary Occupation Race  \
# 0                                   Jim Tullis         politician  NaN
# 2                              Robert L. Clark             lawyer  NaN
# 3                        James Harold Thompson         politician  NaN
# 4                                John U. Lloyd                NaN  NaN
# 5                           Helen Gordon Davis              actor  NaN
# ..                                         ...                ...  ...
# 281                                First Coast                NaN  NaN
# 282                             Atlantic Beach                NaN  NaN
# 285  Archbishop Edward A. McCarthy High School                NaN  NaN
# 286                             Lois D. Martin                NaN  NaN
# 287                              Rush Limbaugh  radio personality  NaN
#
#         Sex  Birth Date  Death Date  \
# 0      male  1941-11-03  2017-10-14
# 2      male  1872-01-31         NaN
# 3      male  1944-11-10         NaN
# 4       NaN         NaN         NaN
# 5    female  1926-12-25  2015-05-18
# ..      ...         ...         ...
# 281     NaN         NaN         NaN
# 282     NaN         NaN         NaN
# 285     NaN         NaN         NaN
# 286  female         NaN  2022-01-09
# 287    male  1951-01-12  2021-02-17
#
#                                         Wikipedia Link  \
# 0             https://en.wikipedia.org/wiki/Jim_Tullis
# 2        https://en.wikipedia.org/wiki/Robert_L._Clark
# 3    https://en.wikipedia.org/wiki/James_Harold_Tho...
# 4    https://en.wikipedia.org/wiki/Dr._Von_D._Mizel...
# 5            https://en.wikipedia.org/wiki/Helen_Davis
# ..                                                 ...
# 281    https://gl.wikipedia.org/wiki/Northeast_Florida
# 282  https://en.wikipedia.org/wiki/Atlantic_Beach,_...
# 285  https://en.wikipedia.org/wiki/Archbishop_Edwar...
# 286       https://en.wikipedia.org/wiki/Lois_D._Martin
# 287        https://en.wikipedia.org/wiki/Rush_Limbaugh
#
#                               original_designation             county  \
# 0                    Jim Tullis Memorial Boulevard              Duval
# 2                 Robert L. Clark Memorial Highway            Broward
# 3                    James Harold Thompson Highway            Gadsden
# 4                             John U. Lloyd Bridge            Broward
# 5                     Helen Gordon Davis Boulevard       Hillsborough
# ..                                             ...                ...
# 281                            First Coast Highway  Multiple Counties
# 282                       Atlantic Beach Boulevard  Multiple Counties
# 285  Archbishop Edward A. McCarthy High School Way            Broward
# 286                             Lois D. Martin Way         Palm Beach
# 287                              Rush Limbaugh Way           Hernando
#
#                                          wikipedia_url  ...  \
# 0        https://en.wikipedia.org/wiki/James_B._Fuller  ...
# 2    https://en.wikipedia.org/wiki/Plantation%2C_Fl...  ...
# 3         https://en.wikipedia.org/wiki/Harold_Sebring  ...
# 4        https://en.wikipedia.org/wiki/John_O%27Hurley  ...
# 5    https://en.wikipedia.org/wiki/Helen_Aguirre_Fe...  ...
# ..                                                 ...  ...
# 281  https://en.wikipedia.org/wiki/First_Coast_High...  ...
# 282       https://en.wikipedia.org/wiki/Atlantic_Beach  ...
# 285        https://en.wikipedia.org/wiki/Justin_Lebron  ...
# 286          https://en.wikipedia.org/wiki/Lois_Lenski  ...
# 287    https://en.wikipedia.org/wiki/John_Catsimatidis  ...
#
#                                              education         dob  \
# 0                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    ["University of Michigan (Bachelor's degree)",...  1893-01-01
# 4                                                  NaN  1954-10-09
# 5    ['University of Miami, Bachelor of Arts in Pol...         NaN
# ..                                                 ...         ...
# 281                                                NaN         NaN
# 282                                                NaN         NaN
# 285                                                NaN         NaN
# 286  ['Ohio State University, Bachelor of Science i...  1893-10-14
# 287                                                NaN  1948-09-07
#
#             dod                    place_of_birth  \
# 0           NaN                         not found
# 2           NaN                         not found
# 3    1980-01-01                         not found
# 4           NaN     Kittery, Maine, United States
# 5           NaN                         not found
# ..          ...                               ...
# 281         NaN                         not found
# 282         NaN                         not found
# 285         NaN                         not found
# 286  1974-09-11  Springfield, Ohio, United States
# 287         NaN       Nisyros, Dodecanese, Greece
#
#                           place_of_death     gender involved_in_sports  \
# 0                              not found       male                 no
# 2                              not found  not found                 no
# 3                              not found       male                yes
# 4                              not found       male                 no
# 5                              not found     female                 no
# ..                                   ...        ...                ...
# 281                            not found  not found                yes
# 282                            not found  not found                 no
# 285                            not found       male                yes
# 286  Tallahassee, Florida, United States     female                 no
# 287                            not found       male                 no
#
#     involved_in_politics involved_in_military involved_in_music
# 0                    yes                   no                no
# 2                     no                   no                no
# 3                     no                  yes                no
# 4                     no                   no                no
# 5                    yes                   no                no
# ..                   ...                  ...               ...
# 281                   no                   no                no
# 282                   no                   no                no
# 285                   no                   no                no
# 286                   no                   no                no
# 287                  yes                   no                no
#
# [253 rows x 25 columns]

# %%
links_match_df.to_csv("links_match.csv", index=False)
links_non_match_df.to_csv("links_non_match.csv", index=False)

# %%
left_join_nulls = left_join_nulls[["Name", "wikipedia_url", "Wikipedia Link", "Does_Sam_Think_is_real"]]

# %%
#161 rows that from wikipedia_api_scraper are not in ai_summarizer
len(left_join_nulls)
# Out:
# 161

# %%
#161 rows from ai_summarizer are not in wikipedia_api_scraper
len(right_join_nulls)
# Out:
# 464
